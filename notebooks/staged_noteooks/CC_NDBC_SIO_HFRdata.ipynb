# %% [markdown]
# ## HF Radar Compliance Checker Script
#
# ### Purpose:
# Run the compliance checker on NDBC and SIO HF radar data to compare the metadata compliance.
#
# ### Dependencies:
# This script must be run in the "I" environment for the compliance checker to work properly.
#
# Written by: JAB

# %%
import compliance_checker

compliance_checker.__version__
# Out:
# '3.0.2'

# %%
# First import the compliance checker and test that it is installed properly
from compliance_checker.runner import ComplianceChecker, CheckSuite

# Load all available checker classes
check_suite = CheckSuite()
check_suite.load_all_available_checkers()

# %%
#Paths to the east coast and Gulf of Mexico 1km resolution HF Radar data 

NDBC_HFR_path = 'http://sdf.ndbc.noaa.gov/thredds/dodsC/hfradar_usegc_1km'

SIO_HFR_path = 'http://hfrnet.ucsd.edu/thredds/dodsC/HFRNet/USEGC/1km/hourly/RTV'

# %% [markdown]
# ### Running Compliance Checker on NDBC THREDDS data

# %%
# Run cf and adcc checks with normal strictness, verbose text format to stdout
return_value, errors = ComplianceChecker.run_checker(
    NDBC_HFR_path,
    checker_names=['cf', 'acdd'],
    verbose=True,
    criteria='normal',
    skip_checks=None,
    output_filename='-',
    output_format='text'
)
# Out:
# --------------------------------------------------------------------------------
#                      The dataset scored 30 out of 71 points
#                              during the acdd check
# --------------------------------------------------------------------------------
#                            Verbose Scoring Breakdown:
#
#                                  High Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# Conventions                             :3:     1/2
# keywords                                :3:     0/1
# summary                                 :3:     1/1
# title                                   :3:     1/1
# varattr                                 :3:    13/29
#     DOPx                                :3:       1/4
#         coverage_content_type           :3:         0/1
#         var_std_name                    :3:         1/2
#         var_units                       :3:         0/1
#     DOPy                                :3:       1/4
#         coverage_content_type           :3:         0/1
#         var_std_name                    :3:         1/2
#         var_units                       :3:         0/1
#     lat                                 :3:       2/3
#         var_std_name                    :3:         1/2
#         var_units                       :3:         1/1
#     lon                                 :3:       2/3
#         var_std_name                    :3:         1/2
#         var_units                       :3:         1/1
#     procParams                          :3:       1/4
#         coverage_content_type           :3:         0/1
#         var_std_name                    :3:         1/2
#         var_units                       :3:         0/1
#     time                                :3:       2/3
#         var_std_name                    :3:         2/2
#         var_units                       :3:         0/1
#     u                                   :3:       2/4
#         coverage_content_type           :3:         0/1
#         var_std_name                    :3:         1/2
#         var_units                       :3:         1/1
#     v                                   :3:       2/4
#         coverage_content_type           :3:         0/1
#         var_std_name                    :3:         1/2
#         var_units                       :3:         1/1
#
#
#                                 Medium Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# acknowledgment/acknowledgement          :2:     0/1
# comment                                 :2:     0/1
# creator_email                           :2:     1/1
# creator_name                            :2:     1/1
# creator_url                             :2:     1/1
# date_created                            :2:     0/1
# date_issued_is_iso                      :2:     0/0
# date_metadata_modified_is_iso           :2:     0/0
# date_modified_is_iso                    :2:     0/0
# geospatial_bounds                       :2:     0/1
# geospatial_bounds_crs                   :2:     0/1
# geospatial_bounds_vertical_crs          :2:     0/1
# geospatial_lat_extents_match            :2:     2/2
# geospatial_lat_max                      :2:     1/1
# geospatial_lat_min                      :2:     1/1
# geospatial_lon_extents_match            :2:     2/2
# geospatial_lon_max                      :2:     1/1
# geospatial_lon_min                      :2:     1/1
# geospatial_vertical_max                 :2:     0/1
# geospatial_vertical_min                 :2:     0/1
# geospatial_vertical_positive            :2:     0/1
# history                                 :2:     1/1
# id                                      :2:     0/1
# id_has_no_blanks                        :2:     0/0
# institution                             :2:     1/1
# license                                 :2:     0/1
# metadata_link                           :2:     0/1
# naming_authority                        :2:     0/1
# processing_level                        :2:     0/1
# project                                 :2:     0/1
# publisher_email                         :2:     0/1
# publisher_name                          :2:     0/1
# publisher_url                           :2:     0/1
# source                                  :2:     1/1
# standard_name_vocabulary                :2:     0/1
# time_coverage_duration                  :2:     0/1
# time_coverage_end                       :2:     0/1
# time_coverage_resolution                :2:     0/1
# time_coverage_start                     :2:     0/1
# time_extents                            :2:     0/0
# vertical_extents                        :2:     0/0
#
#
#                                   Low Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# contributor_name                        :1:     0/1
# contributor_role                        :1:     0/1
# creator_institution                     :1:     0/1
# creator_type                            :1:     0/2
# date_issued                             :1:     0/1
# date_metadata_modified                  :1:     0/1
# date_modified                           :1:     0/1
# geospatial_lat_resolution               :1:     0/1
# geospatial_lat_units                    :1:     0/1
# geospatial_lon_resolution               :1:     0/1
# geospatial_lon_units                    :1:     0/1
# geospatial_vertical_resolution          :1:     0/1
# geospatial_vertical_units               :1:     0/1
# instrument                              :1:     0/1
# instrument_vocabulary                   :1:     0/1
# keywords_vocabulary                     :1:     0/1
# platform                                :1:     0/1
# platform_vocabulary                     :1:     0/1
# product_version                         :1:     1/1
# program                                 :1:     0/1
# publisher_institution                   :1:     0/1
# publisher_type                          :1:     0/2
# references                              :1:     1/1
#
#
# --------------------------------------------------------------------------------
#                   Reasoning for the failed tests given below:
#
#
# Name                             Priority:     Score:Reasoning
# --------------------------------------------------------------------------------
# Conventions                            :3:     1/ 2 : Attr Conventions does not
#                                                       contain 'ACDD-1.3'
# keywords                               :3:     0/ 1 : Attr keywords not present
# varattr                                :3:    13/29 :
#     DOPx                               :3:     1/ 4 :
#         coverage_content_type          :3:     0/ 1 : Var DOPx missing attr
#                                                       coverage_content_type
#         var_std_name                   :3:     1/ 2 : Var DOPx missing attr
#                                                       standard_name
#         var_units                      :3:     0/ 1 : Var DOPx missing attr
#                                                       units
#     DOPy                               :3:     1/ 4 :
#         coverage_content_type          :3:     0/ 1 : Var DOPy missing attr
#                                                       coverage_content_type
#         var_std_name                   :3:     1/ 2 : Var DOPy missing attr
#                                                       standard_name
#         var_units                      :3:     0/ 1 : Var DOPy missing attr
#                                                       units
#     lat                                :3:     2/ 3 :
#         var_std_name                   :3:     1/ 2 : Var lat missing attr
#                                                       long_name
#     lon                                :3:     2/ 3 :
#         var_std_name                   :3:     1/ 2 : Var lon missing attr
#                                                       long_name
#     procParams                         :3:     1/ 4 :
#         coverage_content_type          :3:     0/ 1 : Var procParams missing
#                                                       attr coverage_content_type
#         var_std_name                   :3:     1/ 2 : Var procParams missing
#                                                       attr standard_name
#         var_units                      :3:     0/ 1 : Var procParams missing
#                                                       attr units
#     time                               :3:     2/ 3 :
#         var_units                      :3:     0/ 1 : Var time missing attr
#                                                       units
#     u                                  :3:     2/ 4 :
#         coverage_content_type          :3:     0/ 1 : Var u missing attr
#                                                       coverage_content_type
#         var_std_name                   :3:     1/ 2 : Var u missing attr
#                                                       long_name
#     v                                  :3:     2/ 4 :
#         coverage_content_type          :3:     0/ 1 : Var v missing attr
#                                                       coverage_content_type
#         var_std_name                   :3:     1/ 2 : Var v missing attr
#                                                       long_name
# acknowledgment/acknowledgement         :2:     0/ 1 : acknowledgement global
#                                                       attribute is recommended
# comment                                :2:     0/ 1 : Attr comment not present
# date_created                           :2:     0/ 1 : Attr date_created not
#                                                       present
# geospatial_bounds                      :2:     0/ 1 : Attr geospatial_bounds not
#                                                       present
# geospatial_bounds_crs                  :2:     0/ 1 : Attr geospatial_bounds_crs
#                                                       not present
# geospatial_bounds_vertical_crs         :2:     0/ 1 : Attr
#                                                       geospatial_bounds_vertical
#                                                       _crs not present
# geospatial_vertical_max                :2:     0/ 1 : Attr
#                                                       geospatial_vertical_max
#                                                       not present
# geospatial_vertical_min                :2:     0/ 1 : Attr
#                                                       geospatial_vertical_min
#                                                       not present
# geospatial_vertical_positive           :2:     0/ 1 : Attr
#                                                       geospatial_vertical_positi
#                                                       ve not present
# id                                     :2:     0/ 1 : Attr id not present
# license                                :2:     0/ 1 : Attr license not present
# metadata_link                          :2:     0/ 1 : Attr metadata_link not
#                                                       present
# naming_authority                       :2:     0/ 1 : Attr naming_authority not
#                                                       present
# processing_level                       :2:     0/ 1 : Attr processing_level not
#                                                       present
# project                                :2:     0/ 1 : Attr project not present
# publisher_email                        :2:     0/ 1 : Attr publisher_email not
#                                                       present
# publisher_name                         :2:     0/ 1 : Attr publisher_name not
#                                                       present
# publisher_url                          :2:     0/ 1 : Attr publisher_url not
#                                                       present
# standard_name_vocabulary               :2:     0/ 1 : Attr
#                                                       standard_name_vocabulary
#                                                       not present
# time_coverage_duration                 :2:     0/ 1 : Attr
#                                                       time_coverage_duration not
#                                                       present
# time_coverage_end                      :2:     0/ 1 : Attr time_coverage_end not
#                                                       present
# time_coverage_resolution               :2:     0/ 1 : Attr
#                                                       time_coverage_resolution
#                                                       not present
# time_coverage_start                    :2:     0/ 1 : Attr time_coverage_start
#                                                       not present
# contributor_name                       :1:     0/ 1 : Attr contributor_name not
#                                                       present
# contributor_role                       :1:     0/ 1 : Attr contributor_role not
#                                                       present
# creator_institution                    :1:     0/ 1 : Attr creator_institution
#                                                       not present
# creator_type                           :1:     0/ 2 : Attr creator_type not
#                                                       present
# date_issued                            :1:     0/ 1 : Attr date_issued not
#                                                       present
# date_metadata_modified                 :1:     0/ 1 : Attr
#                                                       date_metadata_modified not
#                                                       present
# date_modified                          :1:     0/ 1 : Attr date_modified not
#                                                       present
# geospatial_lat_resolution              :1:     0/ 1 : Attr
#                                                       geospatial_lat_resolution
#                                                       not present
# geospatial_lat_units                   :1:     0/ 1 : Attr geospatial_lat_units
#                                                       not present
# geospatial_lon_resolution              :1:     0/ 1 : Attr
#                                                       geospatial_lon_resolution
#                                                       not present
# geospatial_lon_units                   :1:     0/ 1 : Attr geospatial_lon_units
#                                                       not present
# geospatial_vertical_resolution         :1:     0/ 1 : Attr
#                                                       geospatial_vertical_resolu
#                                                       tion not present
# geospatial_vertical_units              :1:     0/ 1 : Attr
#                                                       geospatial_vertical_units
#                                                       not present
# instrument                             :1:     0/ 1 : Attr instrument not
#                                                       present
# instrument_vocabulary                  :1:     0/ 1 : Attr instrument_vocabulary
#                                                       not present
# keywords_vocabulary                    :1:     0/ 1 : Attr keywords_vocabulary
#                                                       not present
# platform                               :1:     0/ 1 : Attr platform not present
# platform_vocabulary                    :1:     0/ 1 : Attr platform_vocabulary
#                                                       not present
# program                                :1:     0/ 1 : Attr program not present
# publisher_institution                  :1:     0/ 1 : Attr publisher_institution
#                                                       not present
# publisher_type                         :1:     0/ 2 : Attr publisher_type not
#                                                       present
#
#
# --------------------------------------------------------------------------------
#                     The dataset scored 212 out of 219 points
#                               during the cf check
# --------------------------------------------------------------------------------
#                            Verbose Scoring Breakdown:
#
#                                  High Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# §2.2 Valid netCDF data types            :3:    12/12
# §2.4 Unique dimensions                  :3:    12/12
# §3.1 Variable DOPx contains valid CF un :3:     3/3
# §3.1 Variable DOPy contains valid CF un :3:     3/3
# §3.1 Variable lat contains valid CF uni :3:     3/3
# §3.1 Variable lat's units are appropria :3:     1/1
# §3.1 Variable lon contains valid CF uni :3:     3/3
# §3.1 Variable lon's units are appropria :3:     1/1
# §3.1 Variable procParams contains valid :3:     3/3
# §3.1 Variable site_lat contains valid C :3:     3/3
# §3.1 Variable site_lat's units are appr :3:     1/1
# §3.1 Variable site_lon contains valid C :3:     3/3
# §3.1 Variable site_lon's units are appr :3:     1/1
# §3.1 Variable u contains valid CF units :3:     3/3
# §3.1 Variable u's units are appropriate :3:     1/1
# §3.1 Variable v contains valid CF units :3:     3/3
# §3.1 Variable v's units are appropriate :3:     1/1
# §3.3 Variable lat has valid standard_na :3:     2/2
# §3.3 Variable lon has valid standard_na :3:     2/2
# §3.3 Variable site_lat has valid standa :3:     2/2
# §3.3 Variable site_lon has valid standa :3:     2/2
# §3.3 Variable u has valid standard_name :3:     2/2
# §3.3 Variable v has valid standard_name :3:     2/2
# §3.4 Ancillary Variables defined by u   :3:     2/2
# §3.4 Ancillary Variables defined by v   :3:     2/2
# §4.1 Latitude variable lat has required :3:     1/1
# §4.1 Latitude variable site_lat has req :3:     1/1
# §4.1 Longitude variable lon has require :3:     1/1
# §4.1 Longitude variable site_lon has re :3:     1/1
# §4.4 Time coordinate variable and attri :3:     0/1
# §5.0 Variable DOPx does not contain dup :3:     3/3
# §5.0 Variable DOPy does not contain dup :3:     3/3
# §5.0 Variable procParams does not conta :3:     5/5
# §5.0 Variable u does not contain duplic :3:     3/3
# §5.0 Variable v does not contain duplic :3:     3/3
# §9.1 Dataset contains a valid featureTy :3:     1/1
# §9.1 Feature Types are all the same     :3:     1/1
#
#
#                                 Medium Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# §2.3 Naming Conventions for attributes  :2:    50/54
# §2.3 Naming Conventions for dimensions  :2:     6/6
# §2.3 Naming Conventions for variables   :2:    12/12
# §2.3 Unique variable names              :2:    12/12
# §2.4 Dimension Order                    :2:     9/9
# §2.5.1 Fill Values should be outside th :2:     0/0
# §2.6.1 Global Attribute Conventions inc :2:     0/1
# §2.6.2 Recommended Attributes           :2:     9/9
# §2.6.2 Recommended Global Attributes    :2:     2/2
# §4.1 Latitude variable lat defines eith :2:     1/1
# §4.1 Latitude variable lat uses recomme :2:     1/1
# §4.1 Latitude variable site_lat defines :2:     1/1
# §4.1 Latitude variable site_lat uses re :2:     1/1
# §4.1 Longitude variable lon defines eit :2:     1/1
# §4.1 Longitude variable lon uses recomm :2:     1/1
# §4.1 Longitude variable site_lon define :2:     1/1
# §4.1 Longitude variable site_lon uses r :2:     1/1
# §5.0 multidimensional coordinate time s :2:     0/1
# §8.1 Packed Data defined by DOPx contai :2:     1/1
# §8.1 Packed Data defined by DOPx contai :2:     1/1
# §8.1 Packed Data defined by DOPy contai :2:     1/1
# §8.1 Packed Data defined by DOPy contai :2:     1/1
# §8.1 Packed Data defined by u contains  :2:     1/1
# §8.1 Packed Data defined by u contains  :2:     1/1
# §8.1 Packed Data defined by v contains  :2:     1/1
# §8.1 Packed Data defined by v contains  :2:     1/1
#
#
#                                   Low Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# §3.1 Variable lat's units are contained :1:     1/1
# §3.1 Variable lon's units are contained :1:     1/1
# §3.1 Variable site_lat's units are cont :1:     1/1
# §3.1 Variable site_lon's units are cont :1:     1/1
# §3.1 Variable u's units are contained i :1:     1/1
# §3.1 Variable v's units are contained i :1:     1/1
#
#
# --------------------------------------------------------------------------------
#                   Reasoning for the failed tests given below:
#
#
# Name                             Priority:     Score:Reasoning
# --------------------------------------------------------------------------------
# §4.4 Time coordinate variable and attri:3:     0/ 1 : time does not have units
# §2.3 Naming Conventions for attributes :2:    50/54 : attribute u:_ChunkSize
#                                                       should begin with a letter
#                                                       and be composed of
#                                                       letters, digits, and
#                                                       underscores, attribute
#                                                       v:_ChunkSize should begin
#                                                       with a letter and be
#                                                       composed of letters,
#                                                       digits, and underscores,
#                                                       attribute DOPx:_ChunkSize
#                                                       should begin with a letter
#                                                       and be composed of
#                                                       letters, digits, and
#                                                       underscores, attribute
#                                                       DOPy:_ChunkSize should
#                                                       begin with a letter and be
#                                                       composed of letters,
#                                                       digits, and underscores
# §2.6.1 Global Attribute Conventions inc:2:     0/ 1 : Conventions global
#                                                       attribute does not contain
#                                                       "CF-1.6"
# §5.0 multidimensional coordinate time s:2:     0/ 1 : time shares the same name
#                                                       as one of its dimensions

# %% [markdown]
# ### Running Compliance Checker on Scripps THREDDS data

# %%
# Run cf and adcc checks with normal strictness, verbose text format to stdout
return_value, errors = ComplianceChecker.run_checker(
    SIO_HFR_path,
    checker_names=['cf', 'acdd'],
    verbose=True,
    criteria='normal',
    skip_checks=None,
    output_filename='-',
    output_format='text'
)
# Out:
# --------------------------------------------------------------------------------
#                      The dataset scored 38 out of 75 points
#                              during the acdd check
# --------------------------------------------------------------------------------
#                            Verbose Scoring Breakdown:
#
#                                  High Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# Conventions                             :3:     1/2
# keywords                                :3:     0/1
# summary                                 :3:     1/1
# title                                   :3:     1/1
# varattr                                 :3:    21/33
#     DOPx                                :3:       1/4
#         coverage_content_type           :3:         0/1
#         var_std_name                    :3:         1/2
#         var_units                       :3:         0/1
#     DOPy                                :3:       1/4
#         coverage_content_type           :3:         0/1
#         var_std_name                    :3:         1/2
#         var_units                       :3:         0/1
#     procParams                          :3:       1/4
#         coverage_content_type           :3:         0/1
#         var_std_name                    :3:         1/2
#         var_units                       :3:         0/1
#     site_lat                            :3:       3/3
#         var_std_name                    :3:         2/2
#         var_units                       :3:         1/1
#     site_lon                            :3:       3/3
#         var_std_name                    :3:         2/2
#         var_units                       :3:         1/1
#     time                                :3:       3/3
#         var_std_name                    :3:         2/2
#         var_units                       :3:         1/1
#     time_offset                         :3:       3/4
#         coverage_content_type           :3:         0/1
#         var_std_name                    :3:         2/2
#         var_units                       :3:         1/1
#     u                                   :3:       3/4
#         coverage_content_type           :3:         0/1
#         var_std_name                    :3:         2/2
#         var_units                       :3:         1/1
#     v                                   :3:       3/4
#         coverage_content_type           :3:         0/1
#         var_std_name                    :3:         2/2
#         var_units                       :3:         1/1
#
#
#                                 Medium Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# acknowledgment/acknowledgement          :2:     0/1
# comment                                 :2:     0/1
# creator_email                           :2:     1/1
# creator_name                            :2:     1/1
# creator_url                             :2:     1/1
# date_created                            :2:     0/1
# date_issued_is_iso                      :2:     0/0
# date_metadata_modified_is_iso           :2:     0/0
# date_modified_is_iso                    :2:     0/0
# geospatial_bounds                       :2:     0/1
# geospatial_bounds_crs                   :2:     0/1
# geospatial_bounds_vertical_crs          :2:     0/1
# geospatial_lat_extents_match            :2:     2/2
# geospatial_lat_max                      :2:     1/1
# geospatial_lat_min                      :2:     1/1
# geospatial_lon_extents_match            :2:     2/2
# geospatial_lon_max                      :2:     1/1
# geospatial_lon_min                      :2:     1/1
# geospatial_vertical_max                 :2:     0/1
# geospatial_vertical_min                 :2:     0/1
# geospatial_vertical_positive            :2:     0/1
# history                                 :2:     1/1
# id                                      :2:     0/1
# id_has_no_blanks                        :2:     0/0
# institution                             :2:     1/1
# license                                 :2:     0/1
# metadata_link                           :2:     0/1
# naming_authority                        :2:     0/1
# processing_level                        :2:     0/1
# project                                 :2:     0/1
# publisher_email                         :2:     0/1
# publisher_name                          :2:     0/1
# publisher_url                           :2:     0/1
# source                                  :2:     1/1
# standard_name_vocabulary                :2:     0/1
# time_coverage_duration                  :2:     0/1
# time_coverage_end                       :2:     0/1
# time_coverage_resolution                :2:     0/1
# time_coverage_start                     :2:     0/1
# time_extents                            :2:     0/0
# vertical_extents                        :2:     0/0
#
#
#                                   Low Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# contributor_name                        :1:     0/1
# contributor_role                        :1:     0/1
# creator_institution                     :1:     0/1
# creator_type                            :1:     0/2
# date_issued                             :1:     0/1
# date_metadata_modified                  :1:     0/1
# date_modified                           :1:     0/1
# geospatial_lat_resolution               :1:     0/1
# geospatial_lat_units                    :1:     0/1
# geospatial_lon_resolution               :1:     0/1
# geospatial_lon_units                    :1:     0/1
# geospatial_vertical_resolution          :1:     0/1
# geospatial_vertical_units               :1:     0/1
# instrument                              :1:     0/1
# instrument_vocabulary                   :1:     0/1
# keywords_vocabulary                     :1:     0/1
# platform                                :1:     0/1
# platform_vocabulary                     :1:     0/1
# product_version                         :1:     1/1
# program                                 :1:     0/1
# publisher_institution                   :1:     0/1
# publisher_type                          :1:     0/2
# references                              :1:     1/1
#
#
# --------------------------------------------------------------------------------
#                   Reasoning for the failed tests given below:
#
#
# Name                             Priority:     Score:Reasoning
# --------------------------------------------------------------------------------
# Conventions                            :3:     1/ 2 : Attr Conventions does not
#                                                       contain 'ACDD-1.3'
# keywords                               :3:     0/ 1 : Attr keywords not present
# varattr                                :3:    21/33 :
#     DOPx                               :3:     1/ 4 :
#         coverage_content_type          :3:     0/ 1 : Var DOPx missing attr
#                                                       coverage_content_type
#         var_std_name                   :3:     1/ 2 : Var DOPx missing attr
#                                                       standard_name
#         var_units                      :3:     0/ 1 : Var DOPx missing attr
#                                                       units
#     DOPy                               :3:     1/ 4 :
#         coverage_content_type          :3:     0/ 1 : Var DOPy missing attr
#                                                       coverage_content_type
#         var_std_name                   :3:     1/ 2 : Var DOPy missing attr
#                                                       standard_name
#         var_units                      :3:     0/ 1 : Var DOPy missing attr
#                                                       units
#     procParams                         :3:     1/ 4 :
#         coverage_content_type          :3:     0/ 1 : Var procParams missing
#                                                       attr coverage_content_type
#         var_std_name                   :3:     1/ 2 : Var procParams missing
#                                                       attr standard_name
#         var_units                      :3:     0/ 1 : Var procParams missing
#                                                       attr units
#     time_offset                        :3:     3/ 4 :
#         coverage_content_type          :3:     0/ 1 : Var time_offset missing
#                                                       attr coverage_content_type
#     u                                  :3:     3/ 4 :
#         coverage_content_type          :3:     0/ 1 : Var u missing attr
#                                                       coverage_content_type
#     v                                  :3:     3/ 4 :
#         coverage_content_type          :3:     0/ 1 : Var v missing attr
#                                                       coverage_content_type
# acknowledgment/acknowledgement         :2:     0/ 1 : acknowledgement global
#                                                       attribute is recommended
# comment                                :2:     0/ 1 : Attr comment not present
# date_created                           :2:     0/ 1 : Attr date_created not
#                                                       present
# geospatial_bounds                      :2:     0/ 1 : Attr geospatial_bounds not
#                                                       present
# geospatial_bounds_crs                  :2:     0/ 1 : Attr geospatial_bounds_crs
#                                                       not present
# geospatial_bounds_vertical_crs         :2:     0/ 1 : Attr
#                                                       geospatial_bounds_vertical
#                                                       _crs not present
# geospatial_vertical_max                :2:     0/ 1 : Attr
#                                                       geospatial_vertical_max
#                                                       not present
# geospatial_vertical_min                :2:     0/ 1 : Attr
#                                                       geospatial_vertical_min
#                                                       not present
# geospatial_vertical_positive           :2:     0/ 1 : Attr
#                                                       geospatial_vertical_positi
#                                                       ve not present
# id                                     :2:     0/ 1 : Attr id not present
# license                                :2:     0/ 1 : Attr license not present
# metadata_link                          :2:     0/ 1 : Attr metadata_link not
#                                                       present
# naming_authority                       :2:     0/ 1 : Attr naming_authority not
#                                                       present
# processing_level                       :2:     0/ 1 : Attr processing_level not
#                                                       present
# project                                :2:     0/ 1 : Attr project not present
# publisher_email                        :2:     0/ 1 : Attr publisher_email not
#                                                       present
# publisher_name                         :2:     0/ 1 : Attr publisher_name not
#                                                       present
# publisher_url                          :2:     0/ 1 : Attr publisher_url not
#                                                       present
# standard_name_vocabulary               :2:     0/ 1 : Attr
#                                                       standard_name_vocabulary
#                                                       not present
# time_coverage_duration                 :2:     0/ 1 : Attr
#                                                       time_coverage_duration not
#                                                       present
# time_coverage_end                      :2:     0/ 1 : Attr time_coverage_end not
#                                                       present
# time_coverage_resolution               :2:     0/ 1 : Attr
#                                                       time_coverage_resolution
#                                                       not present
# time_coverage_start                    :2:     0/ 1 : Attr time_coverage_start
#                                                       not present
# contributor_name                       :1:     0/ 1 : Attr contributor_name not
#                                                       present
# contributor_role                       :1:     0/ 1 : Attr contributor_role not
#                                                       present
# creator_institution                    :1:     0/ 1 : Attr creator_institution
#                                                       not present
# creator_type                           :1:     0/ 2 : Attr creator_type not
#                                                       present
# date_issued                            :1:     0/ 1 : Attr date_issued not
#                                                       present
# date_metadata_modified                 :1:     0/ 1 : Attr
#                                                       date_metadata_modified not
#                                                       present
# date_modified                          :1:     0/ 1 : Attr date_modified not
#                                                       present
# geospatial_lat_resolution              :1:     0/ 1 : Attr
#                                                       geospatial_lat_resolution
#                                                       not present
# geospatial_lat_units                   :1:     0/ 1 : Attr geospatial_lat_units
#                                                       not present
# geospatial_lon_resolution              :1:     0/ 1 : Attr
#                                                       geospatial_lon_resolution
#                                                       not present
# geospatial_lon_units                   :1:     0/ 1 : Attr geospatial_lon_units
#                                                       not present
# geospatial_vertical_resolution         :1:     0/ 1 : Attr
#                                                       geospatial_vertical_resolu
#                                                       tion not present
# geospatial_vertical_units              :1:     0/ 1 : Attr
#                                                       geospatial_vertical_units
#                                                       not present
# instrument                             :1:     0/ 1 : Attr instrument not
#                                                       present
# instrument_vocabulary                  :1:     0/ 1 : Attr instrument_vocabulary
#                                                       not present
# keywords_vocabulary                    :1:     0/ 1 : Attr keywords_vocabulary
#                                                       not present
# platform                               :1:     0/ 1 : Attr platform not present
# platform_vocabulary                    :1:     0/ 1 : Attr platform_vocabulary
#                                                       not present
# program                                :1:     0/ 1 : Attr program not present
# publisher_institution                  :1:     0/ 1 : Attr publisher_institution
#                                                       not present
# publisher_type                         :1:     0/ 2 : Attr publisher_type not
#                                                       present
#
#
# --------------------------------------------------------------------------------
#                     The dataset scored 296 out of 305 points
#                               during the cf check
# --------------------------------------------------------------------------------
#                            Verbose Scoring Breakdown:
#
#                                  High Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# §2.2 Valid netCDF data types            :3:    14/14
# §2.4 Unique dimensions                  :3:    14/14
# §3.1 Variable DOPx contains valid CF un :3:     3/3
# §3.1 Variable DOPy contains valid CF un :3:     3/3
# §3.1 Variable lat contains valid CF uni :3:     3/3
# §3.1 Variable lat's units are appropria :3:     1/1
# §3.1 Variable lon contains valid CF uni :3:     3/3
# §3.1 Variable lon's units are appropria :3:     1/1
# §3.1 Variable procParams contains valid :3:     3/3
# §3.1 Variable site_lat contains valid C :3:     3/3
# §3.1 Variable site_lat's units are appr :3:     1/1
# §3.1 Variable site_lon contains valid C :3:     3/3
# §3.1 Variable site_lon's units are appr :3:     1/1
# §3.1 Variable time contains valid CF un :3:     3/3
# §3.1 Variable time's units are appropri :3:     1/1
# §3.1 Variable time_offset contains vali :3:     3/3
# §3.1 Variable time_offset's units are a :3:     0/1
# §3.1 Variable time_run contains valid C :3:     3/3
# §3.1 Variable time_run's units are appr :3:     0/1
# §3.1 Variable u contains valid CF units :3:     3/3
# §3.1 Variable u's units are appropriate :3:     1/1
# §3.1 Variable v contains valid CF units :3:     3/3
# §3.1 Variable v's units are appropriate :3:     1/1
# §3.3 Variable lat has valid standard_na :3:     2/2
# §3.3 Variable lon has valid standard_na :3:     2/2
# §3.3 Variable site_lat has valid standa :3:     2/2
# §3.3 Variable site_lon has valid standa :3:     2/2
# §3.3 Variable time has valid standard_n :3:     2/2
# §3.3 Variable time_offset has valid sta :3:     2/2
# §3.3 Variable time_run has valid standa :3:     2/2
# §3.3 Variable u has valid standard_name :3:     2/2
# §3.3 Variable v has valid standard_name :3:     2/2
# §3.4 Ancillary Variables defined by u   :3:     2/2
# §3.4 Ancillary Variables defined by v   :3:     2/2
# §4.1 Latitude variable lat has required :3:     1/1
# §4.1 Latitude variable site_lat has req :3:     1/1
# §4.1 Longitude variable lon has require :3:     1/1
# §4.1 Longitude variable site_lon has re :3:     1/1
# §4.4 Time coordinate variable and attri :3:     6/6
# §5.0 Auxiliary Coordinates of DOPx must :3:     8/8
# §5.0 Auxiliary Coordinates of DOPy must :3:     8/8
# §5.0 Auxiliary Coordinates of u must ha :3:     8/8
# §5.0 Auxiliary Coordinates of v must ha :3:     8/8
# §5.0 Variable DOPx does not contain dup :3:     4/4
# §5.0 Variable DOPy does not contain dup :3:     4/4
# §5.0 Variable procParams does not conta :3:     7/7
# §5.0 Variable time_offset does not cont :3:     5/5
# §5.0 Variable u does not contain duplic :3:     4/4
# §5.0 Variable v does not contain duplic :3:     4/4
# §9.1 Dataset contains a valid featureTy :3:     0/1
# §9.1 Feature Types are all the same     :3:     1/1
#
#
#                                 Medium Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# §2.3 Naming Conventions for attributes  :2:    67/72
# §2.3 Naming Conventions for dimensions  :2:     6/6
# §2.3 Naming Conventions for variables   :2:    14/14
# §2.3 Unique variable names              :2:    14/14
# §2.4 Dimension Order                    :2:    12/12
# §2.5.1 Fill Values should be outside th :2:     0/0
# §2.6.1 Global Attribute Conventions inc :2:     0/1
# §2.6.2 Recommended Attributes           :2:     9/9
# §2.6.2 Recommended Global Attributes    :2:     2/2
# §4.1 Latitude variable lat defines eith :2:     1/1
# §4.1 Latitude variable lat uses recomme :2:     1/1
# §4.1 Latitude variable site_lat defines :2:     1/1
# §4.1 Latitude variable site_lat uses re :2:     1/1
# §4.1 Longitude variable lon defines eit :2:     1/1
# §4.1 Longitude variable lon uses recomm :2:     1/1
# §4.1 Longitude variable site_lon define :2:     1/1
# §4.1 Longitude variable site_lon uses r :2:     1/1
#
#
#                                   Low Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# §3.1 Variable lat's units are contained :1:     1/1
# §3.1 Variable lon's units are contained :1:     1/1
# §3.1 Variable site_lat's units are cont :1:     1/1
# §3.1 Variable site_lon's units are cont :1:     1/1
# §3.1 Variable time's units are containe :1:     1/1
# §3.1 Variable time_offset's units are c :1:     1/1
# §3.1 Variable time_run's units are cont :1:     1/1
# §3.1 Variable u's units are contained i :1:     1/1
# §3.1 Variable v's units are contained i :1:     1/1
#
#
# --------------------------------------------------------------------------------
#                   Reasoning for the failed tests given below:
#
#
# Name                             Priority:     Score:Reasoning
# --------------------------------------------------------------------------------
# §3.1 Variable time_offset's units are a:3:     0/ 1 : units for variable
#                                                       time_offset must be
#                                                       convertible to s currently
#                                                       they are hours since
#                                                       2012-01-01T00:00:00Z
# §3.1 Variable time_run's units are appr:3:     0/ 1 : units for variable
#                                                       time_run must be
#                                                       convertible to s currently
#                                                       they are hours since
#                                                       2012-01-01T00:00:00Z
# §9.1 Dataset contains a valid featureTy:3:     0/ 1 : GRID is not a valid CF
#                                                       featureType. It must be
#                                                       one of point, timeSeries,
#                                                       trajectory, profile,
#                                                       timeSeriesProfile,
#                                                       trajectoryProfile
# §2.3 Naming Conventions for attributes :2:    67/72 : attribute u:_ChunkSize
#                                                       should begin with a letter
#                                                       and be composed of
#                                                       letters, digits, and
#                                                       underscores, attribute
#                                                       v:_ChunkSize should begin
#                                                       with a letter and be
#                                                       composed of letters,
#                                                       digits, and underscores,
#                                                       attribute DOPx:_ChunkSize
#                                                       should begin with a letter
#                                                       and be composed of
#                                                       letters, digits, and
#                                                       underscores, attribute
#                                                       DOPy:_ChunkSize should
#                                                       begin with a letter and be
#                                                       composed of letters,
#                                                       digits, and underscores,
#                                                       global attribute
#                                                       _CoordSysBuilder should
#                                                       begin with a letter and be
#                                                       composed of letters,
#                                                       digits, and underscores
# §2.6.1 Global Attribute Conventions inc:2:     0/ 1 : Conventions global
#                                                       attribute does not contain
#                                                       "CF-1.6"
